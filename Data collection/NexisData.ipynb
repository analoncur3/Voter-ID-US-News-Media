# %%
import pandas as pd
import requests
import time
import newsplease
from tqdm import tqdm
import json
import os
from newsplease import NewsPlease
from urllib.parse import urlparse

# %%
df = pd.read_csv('C:/Users/analo/OneDrive - UvA/Project/Data/Nexis/articles.csv', encoding= 'unicode_escape')
df.head()
# Out:
#    ID                                        Source_File  \
# 0   1  C:/Users/analo/OneDrive - UvA/Project/Data/Nex...
# 1   2  C:/Users/analo/OneDrive - UvA/Project/Data/Nex...
# 2   3  C:/Users/analo/OneDrive - UvA/Project/Data/Nex...
# 3   4  C:/Users/analo/OneDrive - UvA/Project/Data/Nex...
# 4   5  C:/Users/analo/OneDrive - UvA/Project/Data/Nex...
#
#                  Newspaper        Date      Length  \
# 0  CNN New Day 8:30 AM EST  2021-09-23  2559 words
# 1       The New York Times  2014-11-20  1200 words
# 2       The New York Times  2016-11-07   631 words
# 3       The New York Times  2020-07-03  1722 words
# 4       The New York Times  2017-12-25  1601 words
#
#                                              Section  \
# 0                                NEWS; International
# 1  Section A; Column 0; National Desk; Pg. 3; IDE...
# 2         Section A; Column 0; National Desk; Pg. 12
# 3                                                 US
# ...

# %%
domain = df['Source'].value_counts()
pd.DataFrame(domain)
# Out:
#                     Source
# The New York Times    1121
# MSNBC                  525
# Fox News               392
# CNN                    338

# %%
df = pd.to_datetime(df['Date'])
